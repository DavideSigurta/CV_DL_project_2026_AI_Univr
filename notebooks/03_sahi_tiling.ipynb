# %% [markdown]
# # E3 — SAHI Tiling Inference
#
# **Goal:** Test whether inference-time tiling on the E1a checkpoint matches or exceeds architectural gains.
#
# No retraining. Uses E1a `best.pt` checkpoint.

# %%
import sys
sys.path.append('..')

from src.env import get_paths
from src.sahi_inference import run_sahi_inference

paths = get_paths()
print(f"Data: {paths['data']}")
print(f"Output: {paths['output']}")

# %%
# TODO: load E1a checkpoint, run SAHI inference on val set, compute metrics

# %%
# TODO: compare E3 results with E1a, E1b, E2a, E2b

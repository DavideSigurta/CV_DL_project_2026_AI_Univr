# %% [markdown]
# # E4 — Cross-Cutting Error Analysis
#
# **Goal:** Synthesize results across all 5 configurations.
#
# ## Sections
# - 4.1 Summary metrics table
# - 4.2 PR curves (pedestrian, car)
# - 4.3 Per-class AP heatmap
# - 4.4 GradCAM / EigenCAM analysis on YOLOv5s
# - 4.5 Altitude-performance correlation
# - 4.6 SAHI failure modes
# - 4.7 Answer to research question

# %%
import sys
sys.path.append('..')

from src.env import get_paths
from src.metrics import compute_map, compute_pr_curve
from src.visualization import (
    set_plot_style, plot_per_class_ap_heatmap,
    plot_pr_curve, plot_summary_table, plot_altitude_performance
)

paths = get_paths()
set_plot_style()
print("Analysis setup complete.")

# %%
# TODO: 4.1 Summary table

# %%
# TODO: 4.2 PR curves

# %%
# TODO: 4.3 Per-class AP heatmap

# %%
# TODO: 4.4 GradCAM/EigenCAM

# %%
# TODO: 4.5 Altitude-performance correlation

# %%
# TODO: 4.6 SAHI failure modes

# %%
# TODO: 4.7 Answer to research question
